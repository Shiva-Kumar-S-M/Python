# %% [markdown]
# print("Hello world")

# %%
print( "good morning")
# Out:
# good morning

# %%
print("hello")
# Out:
# hello

# %%
print("good night")
# Out:
# good night

# %%
print("hello")
# Out:
# hello

# %%
x=100
print(x)
# Out:
# 100

# %%
a="Alvas"
print( a)
# Out:
# Alvas

# %%
name_of_student=["Virat","Doni","Bumrah","Pavan"]
print(name_of_student)
# Out:
# ['Virat', 'Doni', 'Bumrah', 'Pavan']

# %%
name_of_teacher=["akarsh","jishan", "dishanth"]k

# %%
print(name_of_teacher)
# Out:
# ['akarsh', 'jishan', 'dishanth']

# %%
x=["500"]

# %% [raw]
# print(x)
